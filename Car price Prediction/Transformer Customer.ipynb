# %%
from sklearn.base import BaseEstimator, TransformerMixin
import numpy as np
from numpy.random import randint

# %%
class CustomTransformer(BaseEstimator, TransformerMixin):
     def fit(self, X, y = None):
          return self
     
     def transform(self, X, y=None):
          X['random_int'] = randint(0, 10, X.shape[0])
          return X

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
df = pd.DataFrame({"a": [1, 2, 3], "b":[4, 5, 6], "c":[7,8,9]})
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
Pipe = Pipeline(steps=[
     ("use_custom_transformer", CustomTransformer())
]
)
transformed_df = Pipe.fit_transform(df)
df
# Out:
#    a  b  c  random_int
# 0  1  4  7           5
# 1  2  5  8           0
# 2  3  6  9           3

# %% [markdown]
# # Design a custom class and fit a pipe line and show me transformation

# %%
class Custom_transformation(BaseEstimator, TransformerMixin):
     def fit(self, X, y = None):
          return self
     
     def transform(self, X, y = None):
          X['Random_data'] = randint(0, 100000, X.shape[0])
          return X
     
     
data = pd.read_excel(r'C:\personal\Sklearn_And_Python_For_Interview\Amzn_india_akshit.xlsx')
data_cols = data.filter(items=['Amount__Hyyzo', 'Amount_Partner_Hyyzo'])
data_cols.fillna(0, inplace=True)
data_cols
# Out:
#     Amount__Hyyzo  Amount_Partner_Hyyzo
# 0           23.73                 23.73
# 1           75.42                 75.42
# 2          875.00                875.00
# 3          199.00                199.00
# 4          618.10                618.10
# ..            ...                   ...
# 64           0.00                516.00
# 65           0.00                463.00
# 66           0.00                589.00
# 67           0.00                138.00
# 68           0.00                 71.00
#
# [69 rows x 2 columns]

# %%
pips = Pipeline(steps=[
     ('Use_CustomTransformer', Custom_transformation())
      
])

ans = pips.fit_transform(data_cols)

ans
# Out:
#     Amount__Hyyzo  Amount_Partner_Hyyzo  Random_data
# 0           23.73                 23.73        21243
# 1           75.42                 75.42        95939
# 2          875.00                875.00        97639
# 3          199.00                199.00        41993
# 4          618.10                618.10        86293
# ..            ...                   ...          ...
# 64           0.00                516.00        80163
# 65           0.00                463.00        12134
# 66           0.00                589.00        60535
# 67           0.00                138.00        47883
# 68           0.00                 71.00        86107
#
# [69 rows x 3 columns]

# %%
data_cols
# Out:
#     Amount__Hyyzo  Amount_Partner_Hyyzo  Random_data
# 0           23.73                 23.73        21243
# 1           75.42                 75.42        95939
# 2          875.00                875.00        97639
# 3          199.00                199.00        41993
# 4          618.10                618.10        86293
# ..            ...                   ...          ...
# 64           0.00                516.00        80163
# 65           0.00                463.00        12134
# 66           0.00                589.00        60535
# 67           0.00                138.00        47883
# 68           0.00                 71.00        86107
#
# [69 rows x 3 columns]

# %%
from sklearn.svm import SVC
from sklearn.decomposition import PCA
estimatiors = [('reduce_dim', PCA()), ('clf', SVC())]
Pipes  = Pipeline(estimatiors)
Pipes
# Out:
# Pipeline(steps=[('reduce_dim', PCA()), ('clf', SVC())])

# %%
class Transform_Custom(BaseEstimator, TransformerMixin):
     def fit(self, X, y = None):
          return self
     
     def fit(self, X, y = None):
          X['random_data'] = randint(0, 10000, X.shape[0])
          return X
     
     
dataset = pd.read_csv(r'C:\personal\Sklearn_And_Python_For_Interview\Car price Prediction\Shahnwazahmadkhan.csv')
Ans = dataset.filter(items=['payout', 'point_post_payout'])
Ans.head()
# Out:
#    payout  point_post_payout
# 0      17                 15
# 1      17                 15
# 2      17                 15
# 3      17                 15
# 4      17                 15

# %%
samp = Pipeline(steps=[("Custom_Transformer", Transform_Custom())])

# %%
samp
# Out:
# Pipeline(steps=[('Custom_Transformer', Transform_Custom())])

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
np.random.seed(0)

# %%
X, y = fetch_openml("titanic", version=1, as_frame=True, return_X_y=True)

# %%
X.head(2)
# Out:
#    pclass                            name     sex      age  sibsp  parch  \
# 0       1   Allen, Miss. Elisabeth Walton  female  29.0000      0      0
# 1       1  Allison, Master. Hudson Trevor    male   0.9167      1      2
#
#    ticket      fare    cabin embarked boat  body  \
# 0   24160  211.3375       B5        S    2   NaN
# 1  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: category
# Categories (2, object): ['0', '1']

# %%
numeric_features = ['age', 'fare']
numeric_transformer = Pipeline(
     steps=[("imputer", SimpleImputer(strategy='most_frequent')), ("scaler", StandardScaler())]
     
)

# %%
categorical_features = ['embarked', 'sex', 'pclass']
categorical_transformer = Pipeline(steps=[("encoder", OneHotEncoder(handle_unknown='ignore')),
                                          ("selector", SelectPercentile(chi2, percentile=50))])

preprocessor = ColumnTransformer(
     transformers = [
          ("num", numeric_transformer, numeric_features),
          ("cat", categorical_features, categorical_transformer)
     ]
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Define feature groups
categorical_features = ['embarked', 'sex', 'pclass']
numerical_features = ['age', 'fare']

# Imputer and transformer for numerical features
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Imputer and transformer for categorical features
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# ColumnTransformer to apply transformations to each group of columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# Pipeline with preprocessor and classifier
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", LogisticRegression())]
)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Fit and evaluate the model
clf.fit(X_train, y_train)
print("Model score: %.3f" % clf.score(X_test, y_test))
# Out:
# Model score: 0.790

# %%
clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'fare']),
#                                                  ('cat',
#                                                   ['embarked', 'sex', 'pclass'],
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore')),
#                                                                   ('selector',
# ...

# %%
subset_feature = ["embarked", "sex", "pclass", "age", "fare"]
X_train, X_test = X_train[subset_feature], X_test[subset_feature]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1047 entries, 1118 to 684
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   embarked  1045 non-null   category
#  1   sex       1047 non-null   category
#  2   pclass    1047 non-null   int64
#  3   age       841 non-null    float64
#  4   fare      1046 non-null   float64
# dtypes: category(2), float64(2), int64(1)
# memory usage: 35.0 KB

# %%
from sklearn.compose import make_column_selector as selector

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, selector(dtype_exclude="category")),
        ("cat", categorical_transformer, selector(dtype_include="category")),
    ]
)
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", LogisticRegression())]
)


clf.fit(X_train, y_train)
print("model score: %.3f" % clf.score(X_test, y_test))
clf
# Out:
# model score: 0.798
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001639F63FFD0>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore')),
#                                                                   ('selector',
# ...

# %%
selector(dtype_exclude="category")(X_train)
# Out:
# ['pclass', 'age', 'fare']

# %%
selector(dtype_include="category")(X_train)
# Out:
# ['embarked', 'sex']

# %%
param_grid = {
    "preprocessor__num__imputer__strategy": ["mean", "median"],
    "preprocessor__cat__selector__percentile": [10, 30, 50, 70],
    "classifier__C": [0.1, 1.0, 10, 100],
}

search_cv = RandomizedSearchCV(clf, param_grid, n_iter=10, random_state=0)
search_cv
# Out:
# RandomizedSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x000001639F63FFD0>),
#                                                                               ('cat',
#                                                                                Pipeline(steps=[('encoder',
# ...

# %%
search_cv.fit(X_train, y_train)

print("Best params:")
print(search_cv.best_params_)
# Out:
# Best params:
# {'preprocessor__num__imputer__strategy': 'mean', 'preprocessor__cat__selector__percentile': 30, 'classifier__C': 100}

# %%
print(f"Internal CV score: {search_cv.best_score_:.3f}")
# Out:
# Internal CV score: 0.786

# %%
import pandas as pd

cv_results = pd.DataFrame(search_cv.cv_results_)
cv_results = cv_results.sort_values("mean_test_score", ascending=False)
cv_results[
    [
        "mean_test_score",
        "std_test_score",
        "param_preprocessor__num__imputer__strategy",
        "param_preprocessor__cat__selector__percentile",
        "param_classifier__C",
    ]
].head(5)
# Out:
#    mean_test_score  std_test_score param_preprocessor__num__imputer__strategy  \
# 7         0.786015        0.031020                                       mean
# 0         0.785063        0.030498                                     median
# 4         0.785063        0.030498                                       mean
# 2         0.785063        0.030498                                       mean
# 3         0.783149        0.030462                                       mean
#
#    param_preprocessor__cat__selector__percentile  param_classifier__C
# 7                                             30                100.0
# 0                                             30                  1.0
# 4                                             10                 10.0
# 2                                             30                  1.0
# 3                                             30                  0.1

# %%
print(
    "accuracy of the best model from randomized search: "
    f"{search_cv.score(X_test, y_test):.3f}"
)
# Out:
# accuracy of the best model from randomized search: 0.798
