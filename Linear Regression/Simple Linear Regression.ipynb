# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\personal\Sklearn_And_Python_For_Interview\Linear Regression\placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel("Package (in lpa)")
# Out:
# Text(0, 0.5, 'Package (in lpa)')

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %% [markdown]
# # to check the output

# %%
import warnings
warnings.filterwarnings('ignore')
lr.predict(X_test.iloc[0].values.reshape(1, 1))
# Out:
# array([3.89111601])

# %%
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# array([3.09324469])

# %%
lr.predict(X_test.iloc[2].values.reshape(1,1))
# Out:
# array([2.38464568])

# %% [markdown]
# # Fit a line

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.xlabel('CGPA')
plt.ylabel("Package(in lpa)")
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# # Find the slop and intercept

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_
b
# Out:
# -0.8961119222429144

# %% [markdown]
# - Behind the scene Linear algo is calculating m and b values and a line after
# - using m and b value for a new value of cgpa it is calculating package

# %%
# y = mx + c
y = m * 8.58 + b
y
# Out:
# array([3.89111601])

# %%
m * 9.6 + b
# Out:
# array([4.46022702])

# %%
m * 100 + b
# Out:
# array([54.89908542])

# %%
Akshit= pd.read_excel(r'C:\personal\Sklearn_And_Python_For_Interview\Akshit_Output_Data.xlsx')
Akshit
# Out:
#       Unique_Id Campaign_Name__Hyyzo  Partner Status__Hyyzo  Amount__Hyyzo  \
# 0    1091266745    Flipkart [CPS] IN  admitad       pending          17999
# 1    1091266932    Flipkart [CPS] IN  admitad       pending            244
# 2    1091267293    Flipkart [CPS] IN  admitad       pending            129
# 3    1091186102    Flipkart [CPS] IN  admitad           NaN           1186
# 4    1091178693    Flipkart [CPS] IN  admitad       pending           2719
# ..          ...                  ...      ...           ...            ...
# 102  1090801067    Flipkart [CPS] IN  admitad       pending            499
# 103  1090792417    Flipkart [CPS] IN  admitad       pending            327
# 104  1090792438    Flipkart [CPS] IN  admitad       pending            173
# 105  1090726563    Flipkart [CPS] IN  admitad       pending            218
# 106  1090711420    Flipkart [CPS] IN  admitad       pending            899
#
# ...

# %%
data = Akshit[['Amount__Hyyzo', 'Payout__Hyyzo']]
data
# Out:
#      Amount__Hyyzo  Payout__Hyyzo
# 0            17999              0
# 1              244              6
# 2              129              3
# 3             1186             27
# 4             2719             49
# ..             ...            ...
# 102            499             14
# 103            327              6
# 104            173              3
# 105            218              6
# 106            899             24
#
# [107 rows x 2 columns]

# %%
A = data.iloc[:, 0: 1]
B = data.iloc[:, -1]
A
# Out:
#      Amount__Hyyzo
# 0            17999
# 1              244
# 2              129
# 3             1186
# 4             2719
# ..             ...
# 102            499
# 103            327
# 104            173
# 105            218
# 106            899
#
# [107 rows x 1 columns]

# %%
B
# Out:
# 0       0
# 1       6
# 2       3
# 3      27
# 4      49
#        ..
# 102    14
# 103     6
# 104     3
# 105     6
# 106    24
# Name: Payout__Hyyzo, Length: 107, dtype: int64

# %%
A_train, A_test, B_train, B_test = train_test_split(A, B, test_size=0.2, random_state=2)

# %%
plt.scatter(data['Amount__Hyyzo'], data['Payout__Hyyzo'])
plt.xlabel('Payout')
plt.ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')

# %%
Lr = LinearRegression()
Lr.fit(A_train, B_train)
# Out:
# LinearRegression()

# %%
Lr.predict(A_test.iloc[0].values.reshape(1,1))
# Out:
# array([8.83137639])

# %%
A_test
# Out:
#      Amount__Hyyzo
# 79             209
# 74             209
# 61             499
# 27             229
# 16             149
# 24             619
# 2              129
# 28             260
# 29             229
# 13             166
# 93             278
# 99             216
# 104            173
# 14             331
# 0            17999
# 21              89
# 3             1186
# 30             229
# 84              55
# 59             369
# 23              89
# 11             185

# %%
B_test
# Out:
# 79      5
# 74      5
# 61     14
# 27      6
# 16      3
# 24     11
# 2       3
# 28     23
# 29      4
# 13     15
# 93      7
# 99      5
# 104     3
# 14      6
# 0       0
# 21      2
# 3      27
# 30      4
# 84      1
# 59     10
# 23      2
# 11      5
# Name: Payout__Hyyzo, dtype: int64

# %%
plt.scatter(data['Amount__Hyyzo'], data['Payout__Hyyzo'])
plt.plot(A_train, Lr.predict(A_train), color = 'red')
plt.xlabel('Payout')
plt.ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')

# %%
M = Lr.coef_
M
# Out:
# array([-9.74253646e-06])

# %%
C = Lr.intercept_
C
# Out:
# 8.833412584605508

# %%
M * 209 + C
# Out:
# array([8.83137639])

# %%
M * 1003 + C
# Out:
# array([8.82364082])
